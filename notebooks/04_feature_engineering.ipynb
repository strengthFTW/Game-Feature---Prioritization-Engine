# %%
import pandas as pd
import joblib
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df = pd.read_csv("../data/processed/preprocessed_reviews.csv")

df.head()
# Out:
#    recommendationid language  \
# 0         153486817  english
# 1         153486487  english
# 2         153486273  english
# 3         153486133  english
# 4         153485556  english
#
#                                               review  timestamp_created  \
# 0  It's very fun. I don't usually like open world...         1702441215
# 1                                                fun         1702440650
# 2                                           Fun game         1702440259
# 3                                          cyberpunk         1702440019
# 4  Coming back to try the game after 2.0 came out...         1702439168
#
#    timestamp_updated  voted_up  votes_up  votes_funny  weighted_vote_score  \
# 0         1702441215      True         0            0                  0.0
# 1         1702440650      True         0            0                  0.0
# 2         1702440259      True         0            0                  0.0
# 3         1702440019      True         0            0                  0.0
# 4         1702439168     False         0            0                  0.0
#
#    comment_count  ...     updated            steamid  num_games_owned  \
# 0              0  ...  2023-12-13  76561198019963558                0
# 1              0  ...  2023-12-13  76561199103884291                0
# 2              0  ...  2023-12-13  76561198131623718              354
# 3              0  ...  2023-12-13  76561198273553741                0
# 4              0  ...  2023-12-13  76561198364138475               86
#
#    num_reviews playtime_forever playtime_last_two_weeks  playtime_at_review  \
# 0            8           2482.0                  2482.0                2452
# 1            9           6634.0                   441.0                6622
# 2            3          10328.0                     3.0               10324
# 3            5           1649.0                  1649.0                1580
# 4            8           4070.0                     9.0                4070
#
#     last_played  review_length  \
# 0  1.702444e+09            209
# 1  1.702441e+09              3
# 2  1.702440e+09              8
# 3  1.702444e+09              9
# 4  1.702439e+09            428
#
#                                         clean_review
# 0  fun dont usually like open world games one nic...
# 1                                                fun
# 2                                           fun game
# 3                                          cyberpunk
# 4  coming back try game came however game wont lo...
#
# [5 rows x 25 columns]

# %%
vectorizer = TfidfVectorizer(
    max_features=5000,
    min_df=5,
    max_df=0.8
)
X = vectorizer.fit_transform(df["clean_review"])

# %%
print(X.shape)
# Out:
# (282547, 5000)

# %%
feature_names = vectorizer.get_feature_names_out()

print(feature_names[:20])
# Out:
# ['aaa' 'abandon' 'abandoned' 'abilities' 'ability' 'able' 'absent'
#  'absolute' 'absolutely' 'absurd' 'abundance' 'abysmal' 'ac' 'accept'
#  'acceptable' 'access' 'accessible' 'accident' 'accidentally' 'accomplish']

# %%
first_review = X[0]

print(first_review)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 20 stored elements and shape (1, 5000)>
#   Coords	Values
#   (0, 1809)	0.14398641524156391
#   (0, 1272)	0.15949508608737117
#   (0, 4741)	0.28521416430838914
#   (0, 2552)	0.13451529030085368
#   (0, 3046)	0.19886567993521773
#   (0, 4932)	0.1565704579587492
#   (0, 1833)	0.1632724669588698
#   (0, 3038)	0.15383978506065765
#   (0, 2944)	0.21638389827305196
#   (0, 4952)	0.24393384304671095
#   (0, 3283)	0.2769723128325363
#   (0, 665)	0.17717215907633205
#   (0, 1426)	0.2543943686323723
#   (0, 1829)	0.17344624193040067
#   (0, 1724)	0.3478154412368716
#   (0, 3646)	0.3194541784663304
#   (0, 415)	0.2023680329851997
#   (0, 1164)	0.26449215684019073
#   (0, 1499)	0.2605678271200202
#   (0, 398)	0.17011993853114235

# %%
joblib.dump(vectorizer, "../models/tfidf_vectorizer.pkl")
# Out:
# ['../models/tfidf_vectorizer.pkl']
